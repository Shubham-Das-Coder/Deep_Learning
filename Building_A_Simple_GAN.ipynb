# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torch.utils.tensorboard import SummaryWriter

# %%
class Discriminator(nn.Module):
    def __init__(self,img_dim):
        super().__init__()
        self.disc=nn.Sequential(
        nn.Linear(img_dim,128),
        nn.LeakyReLU(0.1),
        nn.Linear(128,1),
        nn.Sigmoid(),
        )
    def forward(self,x):
        return self.disc(x)

# %%
class Generator(nn.Module):
    def __init__(self,z_dim,img_dim):
        super().__init__()
        self.gen=nn.Sequential(
        nn.Linear(z_dim,256),
        nn.LeakyReLU(0.1),
        nn.Linear(256,img_dim),
        nn.Tanh(),
        )
    def forward(self,x):
        return self.gen(x)

# %%
device='cuda' if torch.cuda.is_available() else 'cpu'
lr=3e-4
z_dim=64
image_dim=28*28*1
batch_size=32
num_epochs=50
disc=Discriminator(image_dim).to(device)
gen=Generator(z_dim,image_dim).to(device)
fixed_noise=torch.randn((batch_size,z_dim)).to(device)
transforms=transforms.Compose(
            [transforms.ToTensor(),transforms.Normalize((0.5),(0.5))]
)
dataset=datasets.MNIST(root="dataset/",transform=transforms,download=True)
loader=DataLoader(dataset,batch_size=batch_size,shuffle=True)
opt_disc=optim.Adam(disc.parameters(),lr=lr)
opt_gen=optim.Adam(gen.parameters(),lr=lr)
criterion=nn.BCELoss()
writer_fake=SummaryWriter(f"runs/GAN_MNIST/fake")
writer_real=SummaryWriter(f"runs/GAN_MNIST/real")
step=0

# %%
for epoch in range(num_epochs):
    for batch_idx, (real,_) in enumerate(loader):
        real=real.view(-1,784).to(device)
        batch_size=real.shape[0]
        noise=torch.randn(batch_size,z_dim).to(device)
        fake=gen(noise)
        disc_real=disc(real).view(-1)
        lossD_real=criterion(disc_real,torch.ones_like(disc_real))
        disc_fake=disc(fake).view(-1)
        lossD_fake=criterion(disc_real,torch.zeros_like(disc_fake))
        lossD=(lossD_fake+lossD_real)/2
        disc.zero_grad()
        lossD.backward(retain_graph=True)
        opt_disc.step()
        output=disc(fake).view(-1)
        lossG=criterion(output,torch.ones_like(output))
        gen.zero_grad()
        lossG.backward()
        opt_gen.step()
        if batch_idx == 0:
            print(
                f"Epoch [{epoch}/{num_epochs}] Batch {batch_idx}/{len(loader)} \
                      Loss D: {lossD:.4f}, loss G: {lossG:.4f}"
            )
            with torch.no_grad():
                fake = gen(fixed_noise).reshape(-1, 1, 28, 28)
                data = real.reshape(-1, 1, 28, 28)
                img_grid_fake = torchvision.utils.make_grid(fake, normalize=True)
                img_grid_real = torchvision.utils.make_grid(data, normalize=True)

                writer_fake.add_image(
                    "Mnist Fake Images", img_grid_fake, global_step=step
                )
                writer_real.add_image(
                    "Mnist Real Images", img_grid_real, global_step=step
                )
                step += 1
# Out:
# Epoch [0/50] Batch 0/1875                       Loss D: 0.6951, loss G: 0.6901
# Epoch [1/50] Batch 0/1875                       Loss D: 0.6932, loss G: 0.0068
# Epoch [2/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.0072
# Epoch [3/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.0101
# Epoch [4/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.0137
# Epoch [5/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.0194
# Epoch [6/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.0270
# Epoch [7/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.0382
# Epoch [8/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.0530
# Epoch [9/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.0763
# Epoch [10/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.1095
# Epoch [11/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.1383
# Epoch [12/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.1914
# Epoch [13/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.2447
# Epoch [14/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.3101
# Epoch [15/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.3973
# Epoch [16/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.4475
# Epoch [17/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.5028
# Epoch [18/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.5452
# Epoch [19/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.5898
# Epoch [20/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6096
# Epoch [21/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6275
# Epoch [22/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6524
# Epoch [23/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6578
# Epoch [24/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6634
# Epoch [25/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6738
# Epoch [26/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6769
# Epoch [27/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6795
# Epoch [28/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6802
# Epoch [29/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6822
# Epoch [30/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6762
# Epoch [31/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6778
# Epoch [32/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6796
# Epoch [33/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6816
# Epoch [34/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6833
# Epoch [35/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6840
# Epoch [36/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6861
# Epoch [37/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6885
# Epoch [38/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6854
# Epoch [39/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6925
# Epoch [40/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6895
# Epoch [41/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6908
# Epoch [42/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6906
# Epoch [43/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6916
# Epoch [44/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6896
# Epoch [45/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6940
# Epoch [46/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6908
# Epoch [47/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6916
# Epoch [48/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6917
# Epoch [49/50] Batch 0/1875                       Loss D: 0.6931, loss G: 0.6916
